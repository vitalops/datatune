# %%
# Let's start by installing libraries

# %%
# !pip install datatune
# Out:
# Requirement already satisfied: datatune in /usr/local/lib/python3.12/dist-packages (0.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from datatune) (2.0.2)
# Requirement already satisfied: litellm in /usr/local/lib/python3.12/dist-packages (from datatune) (1.76.0)
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.12/dist-packages (from datatune) (2025.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]->datatune) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]->datatune) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]->datatune) (2025.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]->datatune) (25.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]->datatune) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]->datatune) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]->datatune) (0.12.1)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]->datatune) (18.1.0)
# Requirement already satisfied: aiohttp>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm->datatune) (3.12.15)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from litellm->datatune) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm->datatune) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from litellm->datatune) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from litellm->datatune) (4.25.1)
# Requirement already satisfied: openai>=1.99.5 in /usr/local/lib/python3.12/dist-packages (from litellm->datatune) (1.100.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from litellm->datatune) (2.11.7)
# Requirement already satisfied: python-dotenv>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from litellm->datatune) (1.1.1)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from litellm->datatune) (0.11.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from litellm->datatune) (0.21.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm->datatune) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm->datatune) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm->datatune) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm->datatune) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm->datatune) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm->datatune) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm->datatune) (1.20.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm->datatune) (4.10.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm->datatune) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm->datatune) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm->datatune) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm->datatune) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->litellm->datatune) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm->datatune) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm->datatune) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm->datatune) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm->datatune) (0.27.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm->datatune) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm->datatune) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm->datatune) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm->datatune) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm->datatune) (4.14.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/dist-packages (from partd>=1.4.0->dask[dataframe]->datatune) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm->datatune) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm->datatune) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm->datatune) (0.4.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.7.0->litellm->datatune) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.7.0->litellm->datatune) (2.32.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers->litellm->datatune) (0.34.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm->datatune) (3.19.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm->datatune) (1.1.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm->datatune) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm->datatune) (2.5.0)

# %%
import os
import dask.dataframe as dd
import datatune as dt
from datatune.llm.llm import Azure

# %%
# set your LLM API keys

os.environ["AZURE_API_KEY"] = "Your Azure API KEY"
os.environ["AZURE_API_BASE"] = "Your Azure API Base"
os.environ["AZURE_API_VERSION"] = "Your API Version"

# %%
llm = Azure(
    model_name="gpt-4o-mini",
    api_key=os.getenv("AZURE_API_KEY"),
    api_base=os.getenv("AZURE_API_BASE"),
    api_version=os.getenv("AZURE_API_VERSION"),
    tpm=1000000,
    rpm=5000
)

# %%
# Create a Datatune Agent
agent = dt.Agent(llm)

# %%
# Load the famous Titanic dataset
# You can download it from: https://www.kaggle.com/c/titanic/data
# Or use seaborn's built-in version
import seaborn as sns

# Load Titanic dataset
titanic_pandas = sns.load_dataset('titanic')
print("Dataset shape:", titanic_pandas.shape)

# Convert to Dask DataFrame
df = dd.from_pandas(titanic_pandas, npartitions=4)

print("\nOriginal Titanic Dataset:")
print(df.head(10))

print("\nDataset Info:")
print(f"Columns: {list(df.columns)}")
print(f"Total passengers: {len(titanic_pandas)}")
# Out:
# Dataset shape: (891, 15)
#
# Original Titanic Dataset:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False
#
# Dataset Info:
# Columns: ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']
# Total passengers: 891

# %%
# Create family-related features using natural language
prompt = """
Create new columns:
1. 'family_size' = sibsp + parch + 1 (including the person)
2. 'family_category' = 'Solo' if alone, 'Small' if family_size 2-4, 'Large' if 5+
3. 'title' = extract title from who column and give labels Mr, Mrs, Miss, Master, etc, based on if they're adult or not
"""

df_family = agent.do(prompt, df)

print("Family features added:")
result_family = df_family.compute()
# Out:
# 📝Plan: [{'type': 'dask', 'operation': 'add_column', 'params': {'new_column': 'family_size', 'expression': "df['sibsp'] + df['parch'] + 1"}}, {'type': 'primitive', 'operation': 'Map', 'params': {'subprompt': "Categorize family size into 'Solo', 'Small', or 'Large'. 'Solo' if alone, 'Small' if family_size is between 2 and 4, and 'Large' if family_size is 5 or more.", 'input_fields': ['alone', 'family_size'], 'output_fields': ['family_category']}}, {'type': 'primitive', 'operation': 'Map', 'params': {'subprompt': "Extract title from the 'who' column and label them as Mr, Mrs, Miss, Master, etc., based on whether they are an adult or not.", 'input_fields': ['who', 'adult_male'], 'output_fields': ['title']}}]
# 🔍Executing step: {'type': 'dask', 'operation': 'add_column', 'params': {'new_column': 'family_size', 'expression': "df['sibsp'] + df['parch'] + 1"}} 1
# ✅ Executed step: {'type': 'dask', 'operation': 'add_column', 'params': {'new_column': 'family_size', 'expression': "df['sibsp'] + df['parch'] + 1"}}
# 🔍Executing step: {'type': 'primitive', 'operation': 'Map', 'params': {'subprompt': "Categorize family size into 'Solo', 'Small', or 'Large'. 'Solo' if alone, 'Small' if family_size is between 2 and 4, and 'Large' if family_size is 5 or more.", 'input_fields': ['alone', 'family_size'], 'output_fields': ['family_category']}} 1
# ✅ Executed step: {'type': 'primitive', 'operation': 'Map', 'params': {'subprompt': "Categorize family size into 'Solo', 'Small', or 'Large'. 'Solo' if alone, 'Small' if family_size is between 2 and 4, and 'Large' if family_size is 5 or more.", 'input_fields': ['alone', 'family_size'], 'output_fields': ['family_category']}}
# 🔍Executing step: {'type': 'primitive', 'operation': 'Map', 'params': {'subprompt': "Extract title from the 'who' column and label them as Mr, Mrs, Miss, Master, etc., based on whether they are an adult or not.", 'input_fields': ['who', 'adult_male'], 'output_fields': ['title']}} 1
# ✅ Executed step: {'type': 'primitive', 'operation': 'Map', 'params': {'subprompt': "Extract title from the 'who' column and label them as Mr, Mrs, Miss, Master, etc., based on whether they are an adult or not.", 'input_fields': ['who', 'adult_male'], 'output_fields': ['title']}}
# Family features added:
# [17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 1]
# No of rows: 222
# No of api calls: 14
# Number of batches sent:  14
# [17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 2]
# No of rows: 223
# No of api calls: 14
# Number of batches sent:  14
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 17
#
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# 17
#
# {'alone': False, 'family_size': 8, 'family_category': 'Large'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 5, 'family_category': 'Large'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# 17
#
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# 17
#
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# 17
#
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 7, 'family_category': 'Large'}
# {'alone': False, 'family_size': 7, 'family_category': 'Large'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 17
#
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 17
#
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 5, 'family_category': 'Large'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# 17
#
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 17
#
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 7, 'family_category': 'Large'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# 17
#
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 17
#
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 6, 'family_category': 'Large'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 6, 'family_category': 'Large'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 6, 'family_category': 'Large'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 17
#
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 17
#
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 2
#
# 223 rows returned
# [19, 18, 19, 18, 19, 18, 19, 18, 19, 18, 19, 18, 1]
# No of rows: 223
# No of api calls: 13
# Number of batches sent:  13
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 8, 'family_category': 'Large'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 8, 'family_category': 'Large'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# 17
#
# {'alone': False, 'family_size': 6, 'family_category': 'Large'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# 17
#
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 17
#
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 5, 'family_category': 'Large'}
# 17
#
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 5, 'family_category': 'Large'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 17
#
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 17
#
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 5, 'family_category': 'Large'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 6, 'family_category': 'Large'}
# 17
#
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 11, 'family_category': 'Large'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 17
#
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 7, 'family_category': 'Large'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 6, 'family_category': 'Large'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 17
#
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 6, 'family_category': 'Large'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 17
#
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 11, 'family_category': 'Large'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 7, 'family_category': 'Large'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# 17
#
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 11, 'family_category': 'Large'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 3, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 17
#
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': False, 'family_size': 2, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 6, 'family_category': 'Large'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# {'alone': False, 'family_size': 4, 'family_category': 'Small'}
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 17
#
# {'alone': True, 'family_size': 1, 'family_category': 'Solo'}
# 1
#
# 222 rows returned
# [19, 18, 19, 18, 19, 18, 19, 18, 19, 18, 19, 18]
# No of rows: 222
# No of api calls: 12
# Number of batches sent:  12
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 19
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 18
#
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# 19
#
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 18
#
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 19
#
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# 18
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 19
#
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# 18
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# 19
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 18
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# 19
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 18
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 1
#
# 223 rows returned
# [17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 2]
# No of rows: 223
# No of api calls: 14
# Number of batches sent:  14
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 19
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 18
#
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 19
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# 18
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 19
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# 18
#
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# ...
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 18
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# 19
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# 18
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# 19
#
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 18
#
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# 1
#
# 223 rows returned
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# 19
#
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 18
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 19
#
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 18
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 19
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 18
#
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 19
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# 18
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# 19
#
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Miss'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# 18
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 19
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'child', 'adult_male': False, 'title': 'Master'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'woman', 'adult_male': False, 'title': 'Mrs'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 18
#
# {'who': 'man', 'adult_male': True, 'title': 'Mr'}
# 1
#
# 223 rows returned

# %%
final_result = dt.finalize(result_family) # remove metadata created internally
final_result.to_csv("titanic_enhanced.csv", index=False)
print("Enhanced Titanic dataset saved to titanic_enhanced.csv")
# Out:
# Enhanced Titanic dataset saved to titanic_enhanced.csv

# %%
final_result.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  family_size  \
# 0    man        True  NaN  Southampton    no  False            2
# 1  woman       False    C    Cherbourg   yes  False            2
# 2  woman       False  NaN  Southampton   yes   True            1
# 3  woman       False    C  Southampton   yes  False            2
# 4    man        True  NaN  Southampton    no   True            1
#
#   family_category title
# 0           Small    Mr
# 1           Small   Mrs
# 2            Solo   Mrs
# 3           Small   Mrs
# 4            Solo    Mr
